# %% [markdown]
# # 4.6 Taks Pt. 2

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\\Users\\figue\\Instacart Basket Analysis'

# %%
df_ords_prods_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_clean_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'prods_checked.csv'), index_col = False)

# %% [markdown]
# ## Q4)

# %%
df_ords_prods_comb.shape
# Out:
# (32434489, 13)

# %%
df_clean_prods.shape
# Out:
# (49672, 6)

# %% [markdown]
# ## Q5)

# %%
# checking collumn names

df_ords_prods_comb.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# ...

# %%
# Checking collumn names

df_clean_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# ### Merging Data

# %% [markdown]
# #### Clean data tables

# %%
df_ords_prods_comb = df_ords_prods_comb.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0', '_merge'])

# %%
df_clean_prods = df_clean_prods.drop(columns = 'Unnamed: 0')

# %%
df_ords_prods_comb.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df_clean_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# #### Merging the data

# %%
df_ords_prods_merged = df_ords_prods_comb.merge(df_clean_prods, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# ## Q6)

# %%
# Confirming the results

df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ## Q7)

# %%
# Exporting new data

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged.pkl'))
